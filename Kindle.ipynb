# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkachauhan/Facebook--kindle/blob/master/Kindle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files;
uploaded = files.upload()

# %%
from google.colab import files;
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9bd7de00-2bea-4917-acc4-79df64123f12" name="files[]" multiple disabled />
#      <output id="result-9bd7de00-2bea-4917-acc4-79df64123f12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cast3.csv to cast3.csv

# %%
pip install BatAlgorithm

# %%
import random
from BatAlgorithm import *
import pandas as pd
from pandas import read_csv



dataframe = read_csv("cast3.csv")

# for index, row in df.iterrows():
#     print row["c1"], row["c2"]

D = dataframe.shape[0]
d = 7

def Fun(d, sol):
    val = 0.0
#     for i, line in enumerate(dataframe):
#         val = val + sol[i] * sol[i]
        
    for i in range(d):
        val = val + sol[i] * sol[i]
    return val

# For reproducive results
#random.seed(5)

for i in range(D):
    Algorithm = BatAlgorithm(D, 40, 1000, 0.5, 0.5, 0.0, 2.0, -10.0, 10.0, Fun)
    Algorithm.move_bat()
    
# for i, line in enumerate(dataframe):  
#     Algorithm = BatAlgorithm(D, 40, 1000, 0.5, 0.5, 0.0, 2.0, -10.0, 10.0, Fun)
#     Algorithm.move_bat()
# Out:
# 8925.272587783342
# 7247.334308487459
# 7063.131447936446
# 5242.474362213136
# 5648.626280780962
# 5625.156540720423
# 8298.774786423124
# 7971.407795293575
# 8765.426278971885
# 13262.715019128193
# 14424.103916969825
# 8062.243625911518
# 6003.916464007874
# 9167.485633830373
# 11050.396394900208
# 13919.05102044138
# 8363.436517448425
# 7596.926994851939
# 9844.660244388839
# 7921.415762981901
# 8088.5948405519075
# 6921.292792840199
# 5959.058681611673
# 10417.059973218751
# 6407.423461141081
# 9692.601499990617
# 8223.33682542439
# 11714.743785969988
# 5064.699664459338
# 15570.1366609535
# 9450.929312945824
# 5417.444099446498
# 9809.753437272902
# 11441.657860393467
# 8243.371938424676
# 9894.429326427975
# 10663.878947240974
# 8338.74579016039
# 9930.6946360252
# 8322.038024472487
# 8020.327625104078
# 6389.743061677344
# 5197.534382827781
# 8283.026934114143
# 5758.969655800356
# 8184.328539043395
# 6807.121548984907
# 12103.223113459626
# 14515.271514559465
# ...
